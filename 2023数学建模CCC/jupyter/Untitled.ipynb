# %%
import pandas as pd

# %%
df = pd.read_excel('..\data\问题一.xlsx', engine='openpyxl')
df
# Out:
#                 单品编码    单品名称        单品分类编码   分类名称          分类编码  \
# 0       1.029000e+14    牛首生菜  1.011010e+09    花叶类  1.011010e+09
# 1       1.029000e+14   四川红香椿  1.011010e+09  水生根茎类  1.011010e+09
# 2       1.029000e+14  本地小毛白菜  1.011010e+09     茄类  1.011011e+09
# 3       1.029000e+14     白菜苔  1.011010e+09    辣椒类  1.011011e+09
# 4       1.029000e+14      苋菜  1.011010e+09    食用菌  1.011011e+09
# ...              ...     ...           ...    ...           ...
# 878498           NaN     NaN           NaN    NaN           NaN
# 878499           NaN     NaN           NaN    NaN           NaN
# 878500           NaN     NaN           NaN    NaN           NaN
# 878501           NaN     NaN           NaN    NaN           NaN
# 878502           NaN     NaN           NaN    NaN           NaN
#
#                  销售单品编码
# 0       102900005117056
# 1       102900005115960
# 2       102900005117056
# 3       102900005115823
# 4       102900005115908
# ...                 ...
# ...
